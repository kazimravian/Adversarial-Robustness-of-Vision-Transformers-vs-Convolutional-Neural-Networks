# %%
clean_acc = [0.81, 0.79, 0.83, 0.81, 0.80, 0.89, 0.89, 0.88]

adv_acc_fgsm = [0.11, 0.15, 0.11, 0.17, 0.25, 0.17, 0.30, 0.23]
adv_acc_pgd = [0.02, 0.04, 0.0, 0.03, 0.15, 0.12, 0.0, 0.01]
adv_acc_dfa = [0.13, 0.16, 0.13, 0.15, 0.28, 0.31, 0.31, 0.19]

legend = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20, 4))
plt.subplot(131)
plt.scatter(clean_acc, adv_acc_fgsm, c=range(len(legend)), cmap='viridis', s = 1000)
for i, txt in enumerate(legend):
    plt.annotate(txt, (clean_acc[i], adv_acc_fgsm[i]))
plt.title("Clean acc vs Adversarial acc for FGSM")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

plt.subplot(132)
plt.scatter(clean_acc, adv_acc_pgd, c=range(len(legend)), cmap='viridis', s = 1000)
for i, txt in enumerate(legend):
    plt.annotate(txt, (clean_acc[i], adv_acc_pgd[i]))
plt.title("Clean acc vs Adversarial acc for PGD")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')

plt.subplot(133)
plt.scatter(clean_acc, adv_acc_dfa, c=range(len(legend)), cmap='viridis', s = 1000)
for i, txt in enumerate(legend):
    plt.annotate(txt, (clean_acc[i], adv_acc_dfa[i]))
plt.title("Clean acc vs Adversarial acc for DFA")
plt.xlabel('Clean accuracy')
plt.ylabel('Adversarial accuracy')
# Out:
# Text(0, 0.5, 'Adversarial accuracy')

# %% [markdown]
# #Aversarial Robustness of Tatget Models (Vits and CNNs) against Adversarial Perturbation Methods FGSM, PGD, DFA

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_robust_fgsm = [15.58, 18.98, 13.25, 20.98, 31.25, 19.10, 33.70, 26.13]

# %%
# prompt: create comparison plot

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 4))
plt.scatter(target_models, adv_robust_fgsm, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_robust_fgsm[i]))
plt.title("Adversarial robustness of target models against FGSM")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_robust_pgd = [2.46, 5.06, 0.00, 3.70, 18.75, 13.48, 0.00, 1.13]

# %%
plt.figure(figsize = (8, 4))
plt.scatter(target_models, adv_robust_pgd, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_robust_pgd[i]))
plt.title("Adversarial robustness of target models against PGD")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()

# %%
target_models = ['ViT-b16', 'ViT-b32', 'ViT-L16', 'ViT-L32', 'ResNet50', 'VGG19', 'MobileNet', 'DenseNet']
adv_robust_dfa = [16.04, 20.25, 15.66, 18.51, 34.56, 34.83, 34.83, 21.59]

# %%
plt.figure(figsize = (8, 4))
plt.scatter(target_models, adv_robust_dfa, c=range(len(target_models)), cmap='viridis', s = 1000)
for i, txt in enumerate(target_models):
    plt.annotate(txt, (target_models[i], adv_robust_dfa[i]))
plt.title("Adversarial robustness of target models against DFA")
plt.xlabel('Target model')
plt.ylabel('Adversarial robustness')
plt.show()
